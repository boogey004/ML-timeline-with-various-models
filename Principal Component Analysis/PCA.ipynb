# %%
import pandas as pd
df = pd.read_csv('pca_practice_dataset.csv')
df
# Out:
#      length_cm  width_cm  height_cm  weight_kg  surface_area_sqcm  \
# 0        54.97     33.70      19.60      36.67            7188.45
# 1        48.62     30.29      18.55      26.85            5867.47
# 2        56.48     36.05      22.60      46.45            8255.26
# 3        65.23     41.25      26.16      71.07           10947.71
# 4        47.66     25.84      18.39      22.85            5161.63
# ..         ...       ...        ...        ...                ...
# 195      53.85     31.37      20.78      35.63            6917.70
# 196      41.16     21.27      16.06      14.04            3774.32
# 197      51.54     33.63      19.15      33.53            6734.17
# 198      50.58     30.12      19.57      29.82            6199.48
# 199      38.57     25.62      15.99      15.82            4035.16
#
#      length_inches  weight_lbs  sensor_temp_c  sensor_vibration_hz  \
# 0            21.78       80.87          84.84                26.90
# ...

# %%
df.shape
# Out:
# (200, 12)

# %%
df.iloc[0]
# Out:
# length_cm                54.97
# width_cm                 33.70
# height_cm                19.60
# weight_kg                36.67
# surface_area_sqcm      7188.45
# length_inches            21.78
# weight_lbs               80.87
# sensor_temp_c            84.84
# sensor_vibration_hz      26.90
# random_noise_1           54.42
# random_noise_2            0.59
# passed_inspection         1.00
# Name: 0, dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# length_cm              0
# width_cm               0
# height_cm              0
# weight_kg              0
# surface_area_sqcm      0
# length_inches          0
# weight_lbs             0
# sensor_temp_c          0
# sensor_vibration_hz    0
# random_noise_1         0
# random_noise_2         0
# passed_inspection      0
# dtype: int64

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
