# %% [markdown]
# Multi-Linear Regression

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %% [markdown]
# Importing data

# %%
df = pd.read_csv('house_prices_multilinear_regression.csv')
df
# Out:
#      area  bedrooms  age   price
# 0    3974         5   29  663000
# 1    1660         2   13  301700
# 2    2094         3   46  331700
# 3    1930         3   35  329300
# 4    1895         4    6  315600
# ..    ...       ...  ...     ...
# 245  1093         1   22  214100
# 246  3127         4   21  552100
# 247  3731         5    6  655700
# 248   997         2    6  288200
# 249  3829         5   48  631800
#
# [250 rows x 4 columns]

# %% [markdown]
# Exploring Data

# %%
df.shape
# Out:
# (250, 4)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# area        0
# bedrooms    0
# age         0
# price       0
# dtype: int64
